# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from data_loading import loading

# %%
side, facing, nomove = loading()

# %%
print(side)
# Out:
# ['M:\\Sumi Apu Project\\Data\\Horizontal\\100_signal_500.csv', 'M:\\Sumi Apu Project\\Data\\Horizontal\\50_signal_500.csv']

# %%
for i, file in enumerate(side):
    data = pd.read_csv(file)

    plt.figure(i)
    plt.title(file)
    d = data.sample(1).values
    plt.plot(d[0])

plt.show()
